# %% [markdown]
# <a href="https://colab.research.google.com/github/rehmani-saad/20221CCS0109-saad/blob/main/time_seiries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data={
    "Dates":pd.to_datetime(["2022-01-01","2022-01-01","2022-02-02","2022-03-03","2022-04-04","2022-05-05","2022-06-06",]),
    "Value":[10,15,22,28,35,42,48]
}

df=pd.DataFrame(data)
df.set_index("Dates",inplace=True)

plt.figure(figsize=(10,6))
plt.plot(df.index,df["Value"],marker='X')
plt.xlabel("Data")
plt.ylabel("Value")
plt.grid(True)
plt.show()
